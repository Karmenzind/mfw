# %%
from pandas import DataFrame, Series
import pandas as pd
import numpy as np
import matplotlib.pylab as plt

# %matplotlib inline

# 解决中文乱码
plt.rc('font', family='Consolas-with-Yahei')
# plt.rc('font', family='Microsoft YaHei')

data_path = './output/result.csv'

# %%
frame = pd.read_csv(data_path, 
                    sep=',', 
                    names=('id', 'name', 'type', 'score'), 
                    index_col='id')
# id: mongo数据库的_id值
# 不用地名做索引，因为有可能重复
frame = frame[frame.name != '中国']  # 不需要的
frame[:10]  # 数据类型展示，score为地点的得分
# Out:
#                          name  type       score
# id
# 5b000d85200d145b3620042c   福建  dest  211.254553
# 5b000d87200d145b3620062d   长乐  dest  105.032174
# 5b000d8a200d145b3620083d   福州  dest  232.070741
# 5b000d8c200d145b36200a2f   尤溪  dest   45.768713
# 5b000d8e200d145b36200c2b   盘山  dest  293.183098
# 5b000d91200d145b36200e19   上高  dest  285.792507
# 5b000d95200d145b362011fd   永安  dest   75.661646
# 5b000d97200d145b362013eb   桃源  dest  394.742742
# 5b000d9a200d145b36201611   桃园  dest   76.146346
# 5b000d9c200d145b36201803   桂林  dest  310.638367

# %%
# 单独分析dest和poi
dests = DataFrame(frame[frame.type == 'dest'], 
                  columns=['name', 'score'])
dests[:10]
# Out:
#                          name       score
# id
# 5b000d85200d145b3620042c   福建  211.254553
# 5b000d87200d145b3620062d   长乐  105.032174
# 5b000d8a200d145b3620083d   福州  232.070741
# 5b000d8c200d145b36200a2f   尤溪   45.768713
# 5b000d8e200d145b36200c2b   盘山  293.183098
# 5b000d91200d145b36200e19   上高  285.792507
# 5b000d95200d145b362011fd   永安   75.661646
# 5b000d97200d145b362013eb   桃源  394.742742
# 5b000d9a200d145b36201611   桃园   76.146346
# 5b000d9c200d145b36201803   桂林  310.638367

# %%
pois = DataFrame(frame[frame.type == 'poi'], 
                 columns=['name', 'score'])
pois[:10]
# Out:
#                               name       score
# id
# 5b000db1200d145b36202a36  杨墩生态休闲农庄   11.000000
# 5b000db2200d145b36202b39  蒙山国家森林公园   12.000000
# 5b000dbc200d145b36203268       岭角村    7.500000
# 5b000dbd200d145b3620331c       岭脚村    7.500000
# 5b000dbe200d145b362033c9        晓起  130.759600
# 5b000e11200d145b36207a32       南怡岛   23.699483
# 5b000e11200d145b36207a9d       南怡岛   23.699483
# 5b000e12200d145b36207b08      乐天世界   19.293342
# 5b000e12200d145b36207b73       青瓦台   23.368619
# 5b000e15200d145b36207d1b       颐和园   39.187369

# %%
# 简单展示得分
pois[:10].plot(kind='bar', 
               x='name',
               y='score',
               )

# %%
# 对poi和dest进行整体排序
pois = pois.sort_values(by=['score'], ascending=False)
pois[:10]  # 排名前十的poi
# Out:
#                              name       score
# id
# 5b000e3b200d145b36209d30      回民街  309.418429
# 5b001e93200d145b362e5e2a      鼓浪屿  259.441061
# 5b001224200d145b3623cab1  陕西历史博物馆  199.445201
# 5b001a26200d145b362aa972       华山  181.588035
# 5b000e9a200d145b3620eeb3      拙政园  178.778232
# 5b000e3a200d145b36209c80       鼓楼  167.037199
# 5b000ea0200d145b3620f4bb       虎丘  162.847472
# 5b0012c7200d145b36245a62      瘦西湖  159.812390
# 5b000e9f200d145b3620f3a7    苏州博物馆  153.148141
# 5b001a04200d145b362a8445     龙门石窟  151.228324

# %%
pois[:10].plot(kind='bar', 
               x='name',
               y='score',
               )

# %%
# 排名前十的dest
dests = dests.sort_values(by=['score'], ascending=False)
dests[:10]
# Out:
#                          name        score
# id
# 5b000db3200d145b36202bb8   北京  3190.896960
# 5b000db2200d145b36202b5f   南京  2253.985704
# 5b000da7200d145b362021d8   厦门  1838.530613
# 5b000e00200d145b36206d93   上海  1792.885936
# 5b000db5200d145b36202d37   婺源  1732.929167
# 5b000e49200d145b3620a984   黄山  1590.505842
# 5b000e38200d145b36209a6e   西安  1384.504129
# 5b000db7200d145b36202ec7   青岛  1303.912613
# 5b000e22200d145b362087c5   杭州  1269.720456
# 5b000e67200d145b3620c1cc   洛阳  1267.423077

# %%
dests[:10].plot(kind='bar',
                x='name',
                y='score',
                )

# %%
dests.to_csv('./output/dests_sorted.csv')
pois.to_csv('./output/pois_sorted.csv')
